# %%
#!pip install roboflow

# %%
import roboflow

# %%
# !roboflow --version
# !flask --version
# !ultralytics --version
# Out:
# 1.2.11
# Python 3.12.3
# Flask 3.1.2
# Werkzeug 3.1.3
# 'ultralytics' n'est pas reconnu en tant que commande interne
# ou externe, un programme ex�cutable ou un fichier de commandes.

# %%
#!pip install pip install opencv-python
# !python.exe -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\sow\desktop\projet\aircraft_detection\.aircraft_virtual_env\lib\site-packages (24.0)
# Collecting pip
#   Downloading pip-25.3-py3-none-any.whl.metadata (4.7 kB)
# Downloading pip-25.3-py3-none-any.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---- ----------------------------------- 0.2/1.8 MB 3.7 MB/s eta 0:00:01
#    ----------- ---------------------------- 0.5/1.8 MB 6.2 MB/s eta 0:00:01
#    --------------------- ------------------ 1.0/1.8 MB 7.7 MB/s eta 0:00:01
#    --------------------------------- ------ 1.5/1.8 MB 8.6 MB/s eta 0:00:01
#    ---------------------------------------  1.8/1.8 MB 8.7 MB/s eta 0:00:01
#    ---------------------------------------  1.8/1.8 MB 8.7 MB/s eta 0:00:01
#    ---------------------------------------  1.8/1.8 MB 8.7 MB/s eta 0:00:01
#    ---------------------------------------  1.8/1.8 MB 8.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 4.4 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.0
#     Uninstalling pip-24.0:
#       Successfully uninstalled pip-24.0
# Successfully installed pip-25.3

# %%
# !pip --version
# Out:
# pip 25.3 from c:\Users\SOW\Desktop\Projet\Aircraft_detection\.Aircraft_Virtual_Env\Lib\site-packages\pip (python 3.12)

# %%
# !pip install pip install opencv-python
# Out:
# Requirement already satisfied: pip in c:\users\sow\desktop\projet\aircraft_detection\.aircraft_virtual_env\lib\site-packages (25.3)
# ERROR: Could not find a version that satisfies the requirement install (from versions: none)
# ERROR: No matching distribution found for install

# %%
# !python -m ultralytics detect train model=yolov8n.pt data=data/data.yaml epochs=50 imgsz=640
# Out:
# c:\Users\SOW\Desktop\Projet\Aircraft_detection\.Aircraft_Virtual_Env\Scripts\python.exe: No module named ultralytics.__main__; 'ultralytics' is a package and cannot be directly executed
